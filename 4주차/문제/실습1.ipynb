# %%
import pandas as pd

df = pd.read_csv("./경제활동인구.csv", encoding='cp949')

n = {'지역':['중랑구'], '취업자':[207], '실업자':[7], '비경제활동인구':[131]}
newLine = pd.DataFrame(n)
df = pd.concat([df,newLine],ignore_index=True)
df.head(-1)
# Out:
#      지역  비경제활동인구  취업자  실업자
# 0   종로구       61   74    2
# 1    중구       47   70    3
# 2   용산구       71  123    4
# 3   성동구      100  150    5
# 4   광진구      119  192    7
# 5  동대문구      142  170    8

# %%
df["경제활동인구"] = df["취업자"] + df["실업자"]
df["15세 이상 인구"] = df["경제활동인구"] + df["비경제활동인구"]
df["경제활동참가율"]= (df["경제활동인구"] / df["15세 이상 인구"]) * 100

print(df)
# Out:
#      지역  비경제활동인구  취업자  실업자  경제활동인구  15세 이상 인구    경제활동참가율
# 0   종로구       61   74    2      76        137  55.474453
# 1    중구       47   70    3      73        120  60.833333
# 2   용산구       71  123    4     127        198  64.141414
# 3   성동구      100  150    5     155        255  60.784314
# 4   광진구      119  192    7     199        318  62.578616
# 5  동대문구      142  170    8     178        320  55.625000
# 6   중랑구      131  207    7     214        345  62.028986

# %%
toPrint = ['15세 이상 인구', '경제활동인구', '취업자', '실업자', '비경제활동인구', '경제활동참가율']

for x in toPrint:
    print(df[x])
# Out:
# 0    137
# 1    120
# 2    198
# 3    255
# 4    318
# 5    320
# 6    345
# Name: 15세 이상 인구, dtype: int64
# 0     76
# 1     73
# 2    127
# 3    155
# 4    199
# 5    178
# 6    214
# Name: 경제활동인구, dtype: int64
# 0     74
# 1     70
# 2    123
# 3    150
# 4    192
# 5    170
# 6    207
# Name: 취업자, dtype: int64
# 0    2
# 1    3
# 2    4
# 3    5
# 4    7
# 5    8
# 6    7
# Name: 실업자, dtype: int64
# 0     61
# 1     47
# 2     71
# 3    100
# 4    119
# 5    142
# 6    131
# Name: 비경제활동인구, dtype: int64
# 0    55.47%
# 1    60.83%
# 2    64.14%
# 3    60.78%
# 4    62.58%
# 5    55.62%
# 6    62.03%
# Name: 경제활동참가율, dtype: object

# %%
print(df[df["경제활동참가율"] >= 60])
# Out:
#     지역  비경제활동인구  취업자  실업자  경제활동인구  15세 이상 인구    경제활동참가율
# 1   중구       47   70    3      73        120  60.833333
# 2  용산구       71  123    4     127        198  64.141414
# 3  성동구      100  150    5     155        255  60.784314
# 4  광진구      119  192    7     199        318  62.578616
# 6  중랑구      131  207    7     214        345  62.028986
